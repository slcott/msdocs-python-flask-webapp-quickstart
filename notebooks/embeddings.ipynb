# %%
# !pip3 install langchain
# Out:
# zsh:1: /opt/homebrew/bin/pip3: bad interpreter: /opt/homebrew/opt/python@3.13/bin/python3.13: no such file or directory
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: langchain in /Users/slcott/Library/Python/3.9/lib/python/site-packages (0.3.10)
# Requirement already satisfied: async-timeout<5.0.0,>=4.0.0 in /Users/slcott/Library/Python/3.9/lib/python/site-packages (from langchain) (4.0.3)
# Requirement already satisfied: PyYAML>=5.3 in /Users/slcott/Library/Python/3.9/lib/python/site-packages (from langchain) (6.0.2)
# Requirement already satisfied: langchain-text-splitters<0.4.0,>=0.3.0 in /Users/slcott/Library/Python/3.9/lib/python/site-packages (from langchain) (0.3.2)
# Requirement already satisfied: SQLAlchemy<3,>=1.4 in /Users/slcott/Library/Python/3.9/lib/python/site-packages (from langchain) (2.0.36)
# Requirement already satisfied: numpy<2,>=1.22.4 in /Users/slcott/Library/Python/3.9/lib/python/site-packages (from langchain) (1.26.4)
# Requirement already satisfied: requests<3,>=2 in /Users/slcott/Library/Python/3.9/lib/python/site-packages (from langchain) (2.32.3)
# Requirement already satisfied: aiohttp<4.0.0,>=3.8.3 in /Users/slcott/Library/Python/3.9/lib/python/site-packages (from langchain) (3.11.10)
# Requirement already satisfied: pydantic<3.0.0,>=2.7.4 in /Users/slcott/Library/Python/3.9/lib/python/site-packages (from langchain) (2.10.3)
# Requirement already satisfied: langsmith<0.2.0,>=0.1.17 in /Users/slcott/Library/Python/3.9/lib/python/site-packages (from langchain) (0.1.147)
# Requirement already satisfied: langchain-core<0.4.0,>=0.3.22 in /Users/slcott/Library/Python/3.9/lib/python/site-packages (from langchain) (0.3.22)
# Requirement already satisfied: tenacity!=8.4.0,<10,>=8.1.0 in /Users/slcott/Library/Python/3.9/lib/python/site-packages (from langchain) (9.0.0)
# Requirement already satisfied: attrs>=17.3.0 in /Users/slcott/Library/Python/3.9/lib/python/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain) (24.2.0)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /Users/slcott/Library/Python/3.9/lib/python/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain) (1.18.3)
# Requirement already satisfied: multidict<7.0,>=4.5 in /Users/slcott/Library/Python/3.9/lib/python/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain) (6.1.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /Users/slcott/Library/Python/3.9/lib/python/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain) (1.5.0)
# Requirement already satisfied: propcache>=0.2.0 in /Users/slcott/Library/Python/3.9/lib/python/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain) (0.2.1)
# Requirement already satisfied: aiosignal>=1.1.2 in /Users/slcott/Library/Python/3.9/lib/python/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain) (1.3.1)
# Requirement already satisfied: aiohappyeyeballs>=2.3.0 in /Users/slcott/Library/Python/3.9/lib/python/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain) (2.4.4)
# Requirement already satisfied: jsonpatch<2.0,>=1.33 in /Users/slcott/Library/Python/3.9/lib/python/site-packages (from langchain-core<0.4.0,>=0.3.22->langchain) (1.33)
# Requirement already satisfied: packaging<25,>=23.2 in /Users/slcott/Library/Python/3.9/lib/python/site-packages (from langchain-core<0.4.0,>=0.3.22->langchain) (24.2)
# Requirement already satisfied: typing-extensions>=4.7 in /Users/slcott/Library/Python/3.9/lib/python/site-packages (from langchain-core<0.4.0,>=0.3.22->langchain) (4.12.2)
# Requirement already satisfied: jsonpointer>=1.9 in /Users/slcott/Library/Python/3.9/lib/python/site-packages (from jsonpatch<2.0,>=1.33->langchain-core<0.4.0,>=0.3.22->langchain) (3.0.0)
# Requirement already satisfied: orjson<4.0.0,>=3.9.14 in /Users/slcott/Library/Python/3.9/lib/python/site-packages (from langsmith<0.2.0,>=0.1.17->langchain) (3.10.12)
# Requirement already satisfied: httpx<1,>=0.23.0 in /Users/slcott/Library/Python/3.9/lib/python/site-packages (from langsmith<0.2.0,>=0.1.17->langchain) (0.28.1)
# Requirement already satisfied: requests-toolbelt<2.0.0,>=1.0.0 in /Users/slcott/Library/Python/3.9/lib/python/site-packages (from langsmith<0.2.0,>=0.1.17->langchain) (1.0.0)
# Requirement already satisfied: httpcore==1.* in /Users/slcott/Library/Python/3.9/lib/python/site-packages (from httpx<1,>=0.23.0->langsmith<0.2.0,>=0.1.17->langchain) (1.0.7)
# Requirement already satisfied: anyio in /Users/slcott/Library/Python/3.9/lib/python/site-packages (from httpx<1,>=0.23.0->langsmith<0.2.0,>=0.1.17->langchain) (4.7.0)
# Requirement already satisfied: certifi in /Users/slcott/Library/Python/3.9/lib/python/site-packages (from httpx<1,>=0.23.0->langsmith<0.2.0,>=0.1.17->langchain) (2024.8.30)
# Requirement already satisfied: idna in /Users/slcott/Library/Python/3.9/lib/python/site-packages (from httpx<1,>=0.23.0->langsmith<0.2.0,>=0.1.17->langchain) (3.10)
# Requirement already satisfied: h11<0.15,>=0.13 in /Users/slcott/Library/Python/3.9/lib/python/site-packages (from httpcore==1.*->httpx<1,>=0.23.0->langsmith<0.2.0,>=0.1.17->langchain) (0.14.0)
# Requirement already satisfied: pydantic-core==2.27.1 in /Users/slcott/Library/Python/3.9/lib/python/site-packages (from pydantic<3.0.0,>=2.7.4->langchain) (2.27.1)
# Requirement already satisfied: annotated-types>=0.6.0 in /Users/slcott/Library/Python/3.9/lib/python/site-packages (from pydantic<3.0.0,>=2.7.4->langchain) (0.7.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /Users/slcott/Library/Python/3.9/lib/python/site-packages (from requests<3,>=2->langchain) (3.4.0)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /Users/slcott/Library/Python/3.9/lib/python/site-packages (from requests<3,>=2->langchain) (2.2.3)
# Requirement already satisfied: sniffio>=1.1 in /Users/slcott/Library/Python/3.9/lib/python/site-packages (from anyio->httpx<1,>=0.23.0->langsmith<0.2.0,>=0.1.17->langchain) (1.3.1)
# Requirement already satisfied: exceptiongroup>=1.0.2 in /Users/slcott/Library/Python/3.9/lib/python/site-packages (from anyio->httpx<1,>=0.23.0->langsmith<0.2.0,>=0.1.17->langchain) (1.2.2)
# WARNING: You are using pip version 21.2.4; however, version 24.3.1 is available.
# You should consider upgrading via the '/Library/Developer/CommandLineTools/usr/bin/python3 -m pip install --upgrade pip' command.

# %%
# !pip3 list
# Out:
# zsh:1: /opt/homebrew/bin/pip3: bad interpreter: /opt/homebrew/opt/python@3.13/bin/python3.13: no such file or directory
# Package                   Version
# ------------------------- --------------
# aiohappyeyeballs          2.4.4
# aiohttp                   3.11.10
# aiosignal                 1.3.1
# altgraph                  0.17.2
# annotated-types           0.7.0
# anyio                     4.7.0
# appnope                   0.1.4
# argon2-cffi               23.1.0
# argon2-cffi-bindings      21.2.0
# arrow                     1.3.0
# asttokens                 3.0.0
# async-lru                 2.0.4
# async-timeout             4.0.3
# attrs                     24.2.0
# babel                     2.16.0
# beautifulsoup4            4.12.3
# bleach                    6.2.0
# certifi                   2024.8.30
# cffi                      1.17.1
# charset-normalizer        3.4.0
# comm                      0.2.2
# debugpy                   1.8.9
# decorator                 5.1.1
# defusedxml                0.7.1
# exceptiongroup            1.2.2
# executing                 2.1.0
# fastjsonschema            2.21.1
# fqdn                      1.5.1
# frozenlist                1.5.0
# future                    0.18.2
# h11                       0.14.0
# httpcore                  1.0.7
# httpx                     0.28.1
# idna                      3.10
# importlib_metadata        8.5.0
# ipykernel                 6.29.5
# ipython                   8.18.1
# ipywidgets                8.1.5
# isoduration               20.11.0
# jedi                      0.19.2
# Jinja2                    3.1.4
# json5                     0.10.0
# jsonpatch                 1.33
# jsonpointer               3.0.0
# jsonschema                4.23.0
# jsonschema-specifications 2024.10.1
# jupyter                   1.1.1
# jupyter_client            8.6.3
# jupyter-console           6.6.3
# jupyter_core              5.7.2
# jupyter-events            0.10.0
# jupyter-lsp               2.2.5
# jupyter_server            2.14.2
# jupyter_server_terminals  0.5.3
# jupyterlab                4.3.2
# jupyterlab_pygments       0.3.0
# jupyterlab_server         2.27.3
# jupyterlab_widgets        3.0.13
# langchain                 0.3.10
# langchain-core            0.3.22
# langchain-text-splitters  0.3.2
# langsmith                 0.1.147
# macholib                  1.15.2
# MarkupSafe                3.0.2
# matplotlib-inline         0.1.7
# mistune                   3.0.2
# multidict                 6.1.0
# nbclient                  0.10.1
# nbconvert                 7.16.4
# nbformat                  5.10.4
# nest-asyncio              1.6.0
# notebook                  7.3.1
# notebook_shim             0.2.4
# numpy                     1.26.4
# orjson                    3.10.12
# overrides                 7.7.0
# packaging                 24.2
# pandocfilters             1.5.1
# parso                     0.8.4
# pexpect                   4.9.0
# pip                       21.2.4
# platformdirs              4.3.6
# prometheus_client         0.21.1
# prompt_toolkit            3.0.48
# propcache                 0.2.1
# psutil                    6.1.0
# ptyprocess                0.7.0
# pure_eval                 0.2.3
# pycparser                 2.22
# pydantic                  2.10.3
# pydantic_core             2.27.1
# Pygments                  2.18.0
# python-dateutil           2.9.0.post0
# python-json-logger        2.0.7
# PyYAML                    6.0.2
# pyzmq                     26.2.0
# referencing               0.35.1
# requests                  2.32.3
# requests-toolbelt         1.0.0
# rfc3339-validator         0.1.4
# rfc3986-validator         0.1.1
# rpds-py                   0.22.3
# Send2Trash                1.8.3
# setuptools                58.0.4
# six                       1.15.0
# sniffio                   1.3.1
# soupsieve                 2.6
# SQLAlchemy                2.0.36
# stack-data                0.6.3
# tenacity                  9.0.0
# terminado                 0.18.1
# tinycss2                  1.4.0
# tomli                     2.2.1
# tornado                   6.4.2
# traitlets                 5.14.3
# types-python-dateutil     2.9.0.20241206
# typing_extensions         4.12.2
# uri-template              1.3.0
# urllib3                   2.2.3
# wcwidth                   0.2.13
# webcolors                 24.11.1
# webencodings              0.5.1
# websocket-client          1.8.0
# wheel                     0.37.0
# widgetsnbextension        4.0.13
# yarl                      1.18.3
# zipp                      3.21.0
# WARNING: You are using pip version 21.2.4; however, version 24.3.1 is available.
# You should consider upgrading via the '/Library/Developer/CommandLineTools/usr/bin/python3 -m pip install --upgrade pip' command.

# %%
from langchain.embeddings import HuggingFaceEmbeddings


modelPath = "BAAI/bge-large-en-v1.5"

# Create a dictionary with model configuration options, specifying to use the CPU for computations
model_kwargs = {'device':'cpu'}
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 from langchain.embeddings import HuggingFaceEmbeddings
#       4 modelPath = "BAAI/bge-large-en-v1.5"
#       6 # Create a dictionary with model configuration options, specifying to use the CPU for computations
#
# ModuleNotFoundError: No module named 'langchain'

# %%
import langchain
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 import langchain
#
# ModuleNotFoundError: No module named 'langchain'

# %%
import
